# %%
import nbformat
files = ['Practice from 2026-04-06 (1) (1) (1).ipynb', 'Practice from 2026-04-06 (1).ipynb', 'Practice from 2026-04-06.ipynb']
merged_nb = nbformat.v4.new_notebook()
for i in files:
    with open(f, 'r', encodig='utf-8') as nbf:
        nb = nbformat.read(nbf, as_version=4)
        merged_nb.cells.extend(nb.cells)
with open('merged_all.ipynb', 'w', encoding='utf-8') as f:
    nbformat.write(merged_nb, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 merged_nb = nbformat.v4.new_notebook()
#       4 for i in files:
# ----> 5     with open(f, 'r', encodig='utf-8') as nbf:
#       6         nb = nbformat.read(nbf, as_version=4)
#       7         merged_nb.cells.extend(nb.cells)
#
# NameError: name 'f' is not defined
